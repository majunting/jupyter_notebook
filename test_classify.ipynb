# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix

# %%
df = pd.read_csv("test_classification_data.csv", )
X = df.drop('Class', axis = 1)
Y = df['Class']

# %%
for i in range (0, 10):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.15)

    SVClassifier = SVC(kernel = 'poly', degree = i)
#     SVClassifier = SVC(kernel = 'linear')
    SVClassifier.fit(X_train, Y_train)

    y_train_pred = SVClassifier.predict(X_train)
    y_test_pred = SVClassifier.predict(X_test)

    print(confusion_matrix(y_train_pred, Y_train))
    print(classification_report(y_train_pred, Y_train))
    print(confusion_matrix(y_test_pred, Y_test))
    print()
# Out:
# [[16  8]
#  [ 0  0]]
#               precision    recall  f1-score   support
#
#            C       1.00      0.67      0.80        24
#            H       0.00      0.00      0.00         0
#
#     accuracy                           0.67        24
#    macro avg       0.50      0.33      0.40        24
# weighted avg       1.00      0.67      0.80        24
#
# [[4 1]
#  [0 0]]
#
# [[16  8]
#  [ 0  0]]
#               precision    recall  f1-score   support
#
#            C       1.00      0.67      0.80        24
#            H       0.00      0.00      0.00         0
#
#     accuracy                           0.67        24
#    macro avg       0.50      0.33      0.40        24
# weighted avg       1.00      0.67      0.80        24
#
# [[4 1]
#  [0 0]]
#
# [[16  4]
#  [ 0  4]]
#               precision    recall  f1-score   support
#
#            C       1.00      0.80      0.89        20
#            H       0.50      1.00      0.67         4
#
#     accuracy                           0.83        24
#    macro avg       0.75      0.90      0.78        24
# weighted avg       0.92      0.83      0.85        24
#
# [[2 0]
#  [2 1]]
#
# [[18  5]
#  [ 0  1]]
#               precision    recall  f1-score   support
#
#            C       1.00      0.78      0.88        23
#            H       0.17      1.00      0.29         1
#
#     accuracy                           0.79        24
#    macro avg       0.58      0.89      0.58        24
# weighted avg       0.97      0.79      0.85        24
#
# [[2 3]
#  [0 0]]
#
# [[17  4]
#  [ 0  3]]
#               precision    recall  f1-score   support
#
#            C       1.00      0.81      0.89        21
#            H       0.43      1.00      0.60         3
#
#     accuracy                           0.83        24
#    macro avg       0.71      0.90      0.75        24
# weighted avg       0.93      0.83      0.86        24
#
# [[3 2]
#  [0 0]]
#
# [[17  4]
#  [ 0  3]]
#               precision    recall  f1-score   support
#
#            C       1.00      0.81      0.89        21
#            H       0.43      1.00      0.60         3
#
#     accuracy                           0.83        24
#    macro avg       0.71      0.90      0.75        24
# weighted avg       0.93      0.83      0.86        24
#
# [[3 2]
#  [0 0]]
#
# [[16  2]
#  [ 0  6]]
#               precision    recall  f1-score   support
#
#            C       1.00      0.89      0.94        18
#            H       0.75      1.00      0.86         6
#
#     accuracy                           0.92        24
#    macro avg       0.88      0.94      0.90        24
# weighted avg       0.94      0.92      0.92        24
#
# [[1 1]
#  [3 0]]
#
# [[18  1]
#  [ 0  5]]
#               precision    recall  f1-score   support
#
#            C       1.00      0.95      0.97        19
#            H       0.83      1.00      0.91         5
#
#     accuracy                           0.96        24
#    macro avg       0.92      0.97      0.94        24
# weighted avg       0.97      0.96      0.96        24
#
# [[0 2]
#  [2 1]]
#
# [[17  4]
#  [ 0  3]]
#               precision    recall  f1-score   support
#
#            C       1.00      0.81      0.89        21
#            H       0.43      1.00      0.60         3
#
#     accuracy                           0.83        24
#    macro avg       0.71      0.90      0.75        24
# weighted avg       0.93      0.83      0.86        24
#
# [[3 1]
#  [0 1]]
#
# [[16  2]
#  [ 0  6]]
#               precision    recall  f1-score   support
#
#            C       1.00      0.89      0.94        18
#            H       0.75      1.00      0.86         6
#
#     accuracy                           0.92        24
#    macro avg       0.88      0.94      0.90        24
# weighted avg       0.94      0.92      0.92        24
#
# [[4 1]
#  [0 0]]
# C:\Users\juntingma\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\juntingma\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
