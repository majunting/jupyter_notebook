# %% [markdown]
# # Train / Test

# %% [markdown]
# We'll start by creating some data set that we want to build a model for (in this case a polynomial regression):

# %%
# %matplotlib inline
import numpy as np
from pylab import *

np.random.seed(2)

pageSpeeds = np.random.normal(3.0, 1.0, 100)
purchaseAmount = np.random.normal(50.0, 30.0, 100) / pageSpeeds


scatter(pageSpeeds, purchaseAmount)

# %% [markdown]
# Now we'll split the data in two - 80% of it will be used for "training" our model, and the other 20% for testing it. This way we can avoid overfitting.

# %%
trainX = pageSpeeds[:80]
testX = pageSpeeds[80:]

trainY = purchaseAmount[:80]
testY = purchaseAmount[80:]

# %% [markdown]
# Here's our training dataset:

# %%
scatter(trainX, trainY)

# %% [markdown]
# And our test dataset:

# %%
scatter(testX, testY)

# %% [markdown]
# Now we'll try to fit an 8th-degree polynomial to this data (which is almost certainly overfitting, given what we know about how it was generated!)

# %%
x = np.array(trainX)
y = np.array(trainY)

p4 = np.poly1d(np.polyfit(x, y, 8))

# %% [markdown]
# Let's plot our polynomial against the training data:

# %%
import matplotlib.pyplot as plt

xp = np.linspace(0, 7, 100)
axes = plt.axes()
axes.set_xlim([0,7])
axes.set_ylim([0, 200])
plt.scatter(x, y)
plt.plot(xp, p4(xp), c='r')
plt.show()

# %% [markdown]
# And against our test data:

# %%
testx = np.array(testX)
testy = np.array(testY)

axes = plt.axes()
axes.set_xlim([0,7])
axes.set_ylim([0, 200])
plt.scatter(testx, testy)
plt.plot(xp, p4(xp), c='r')
plt.show()

# %% [markdown]
# Doesn't look that bad when you just eyeball it, but the r-squared score on the test data is kind of horrible! This tells us that our model isn't all that great...

# %%
from sklearn.metrics import r2_score

r2 = r2_score(testy, p4(testx))

print(r2)
# Out:
# 0.3001816861264437

# %% [markdown]
# ...even though it fits the training data better:

# %%
from sklearn.metrics import r2_score

r2 = r2_score(np.array(trainY), p4(np.array(trainX)))

print(r2)
# Out:
# 0.6427069514692639

# %% [markdown]
# If you're working with a Pandas DataFrame (using tabular, labeled data,) scikit-learn has built-in train_test_split functions to make this easy to do.
#
# Later we'll talk about even more robust forms of train/test, like K-fold cross-validation - where we try out multiple different splits of the data, to make sure we didn't just get lucky with where we split it.

# %% [markdown]
# ## Activity

# %% [markdown]
# Try measuring the error on the test data using different degree polynomial fits. What degree works best?

# %%
for deg in range (0, 20):
    print("--------------------------------------")
    print(deg)
    p4 = np.poly1d(np.polyfit(x, y, deg))
    
#     xp = np.linspace(0, 7, 100)
#     axes = plt.axes()
#     axes.set_xlim([0,7])
#     axes.set_ylim([0, 200])
#     plt.scatter(x, y)
#     plt.plot(xp, p4(xp), c='r')
#     plt.show()
    
#     axes = plt.axes()
#     axes.set_xlim([0,7])
#     axes.set_ylim([0, 200])
#     plt.scatter(testx, testy)
#     plt.plot(xp, p4(xp), c='r')
#     plt.show()
    
    xp = np.linspace(0, 7, 100)
    fig, (ax1, ax2) = plt.subplots(1, 2)
    ax1.set_xlim([0,7])
    ax1.set_ylim([0, 200])
    ax1.scatter(x, y)
    ax1.plot(xp, p4(xp), c='r')
    
    ax2.set_xlim([0,7])
    ax2.set_ylim([0, 200])
    ax2.scatter(testx, testy)
    ax2.plot(xp, p4(xp), c='r')
    plt.show()
    
    r2 = r2_score(testy, p4(testx))
    print("test dataset R2: ", r2)
    r2 = r2_score(np.array(trainY), p4(np.array(trainX)))
    print("training dataset R2: ",r2)
# Out:
# --------------------------------------
# 0
# test dataset R2:  -0.0334054228541838
# training dataset R2:  0.0
# --------------------------------------
# 1
# test dataset R2:  0.4225414067989236
# training dataset R2:  0.2646676132565092
# --------------------------------------
# 2
# test dataset R2:  0.29350317937846726
# training dataset R2:  0.36158094628302195
# --------------------------------------
# 3
# test dataset R2:  0.2727431147520042
# training dataset R2:  0.4295783201206691
# --------------------------------------
# 4
# test dataset R2:  0.39362692609904704
# training dataset R2:  0.48312216559720467
# --------------------------------------
# 5
# test dataset R2:  0.5040723897195025
# training dataset R2:  0.5544872536567733
# --------------------------------------
# 6
# test dataset R2:  0.6050119470356534
# training dataset R2:  0.6025441707110398
# --------------------------------------
# 7
# test dataset R2:  0.5461451452854302
# training dataset R2:  0.6170116571732512
# --------------------------------------
# 8
# test dataset R2:  0.3001816861264437
# training dataset R2:  0.6427069514692639
# --------------------------------------
# 9
# test dataset R2:  0.21615509559902657
# training dataset R2:  0.6633603298433155
# --------------------------------------
# 10
# test dataset R2:  0.2248516782046196
# training dataset R2:  0.6818575244290919
# --------------------------------------
# 11
# test dataset R2:  0.26817765273416694
# training dataset R2:  0.6875191068011847
# --------------------------------------
# 12
# test dataset R2:  0.05952681662374937
# training dataset R2:  0.691855496978614
# --------------------------------------
# 13
# test dataset R2:  0.22596055131851756
# training dataset R2:  0.7050450575043905
# --------------------------------------
# 14
# test dataset R2:  0.29377245304607447
# training dataset R2:  0.7073302823730996
# --------------------------------------
# 15
# test dataset R2:  0.13254194768427863
# training dataset R2:  0.7092487823891296
# --------------------------------------
# 16
# test dataset R2:  -3.7490687345692875
# training dataset R2:  0.7385158226081499
# --------------------------------------
# 17
# test dataset R2:  -19.86508826079795
# training dataset R2:  0.7852649572399509
# --------------------------------------
# 18
# C:\Users\juntingma\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3343: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# test dataset R2:  -15.056224685447685
# training dataset R2:  0.7796027202604169
# --------------------------------------
# 19
# C:\Users\juntingma\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3343: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# test dataset R2:  -11.263876744852745
# training dataset R2:  0.7730006251688702
