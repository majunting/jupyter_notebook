# %% [markdown]
# # Standard Deviation and Variance

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

incomes = np.random.normal(100.0, 50.0, 10000)

plt.hist(incomes, 50)
plt.show()

# %%
incomes.std()
# Out:
# 49.65063205356264

# %%
incomes.var()
# Out:
# 2465.1852633182616

# %% [markdown]
# ## Activity

# %% [markdown]
# Experiment with different parameters on the normal function, and see what effect it has on the shape of the distribution. How does that new shape relate to the standard deviation and variance?

# %%
incomes = np.random.normal(100.0, 20.0, 10000)

plt.hist(incomes, 50)
plt.show()
print(incomes.std())
print(incomes.var())

print("---------------------------------")
incomes = np.random.normal(500.0, 20.0, 10000)

plt.hist(incomes, 50)
plt.show()
print(incomes.std())
print(incomes.var())

print("---------------------------------")
incomes = np.random.normal(100.0, 100.0, 10000)

plt.hist(incomes, 50)
plt.show()
print(incomes.std())
print(incomes.var())

print("---------------------------------")
incomes = np.random.normal(100.0, 0, 10000)

plt.hist(incomes, 50)
plt.show()
print(incomes.std())
print(incomes.var())
# Out:
# 19.952353294019403
# 398.09640196936687
# ---------------------------------
# 20.078362141686988
# 403.1406262927293
# ---------------------------------
# 98.58115406031814
# 9718.24393586418
# ---------------------------------
# 0.0
# 0.0
